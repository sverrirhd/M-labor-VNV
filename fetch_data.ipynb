# %%
    response = requests.post(url, json=params)
    response.raise_for_status()
    response_text = response.text
    data = pd.read_csv(StringIO(response_text))
    data
# Out:
# Empty DataFrame
# ...

# %%
import pandas as pd
import requests
from io import StringIO

# API URL and request parameters
url = "https://px.hagstofa.is:443/pxis/api/v1/is/Efnahagur/visitolur/1_vnv/1_vnv/VIS01000.px"
params = {
  "query": [],
  "response": {
    "format": "json-stat"
  }
}


def fetch_data():
    response = requests.post(url, json=params)
    response.raise_for_status()
    response_text = response.text
    data = pd.read_csv(StringIO(response_text))
    
    data = data.loc[:, ['Mánuður', 'Vísitala neysluverðs Vísitala']]
    # Fix format: 1988M05
    data['Mánuður'] = pd.to_datetime(data['Mánuður'], format='%YM%m')
    # rename to date
    data = data.rename(columns={'Mánuður': 'date'})
    # rename to cpi
    data = data.rename(columns={'Vísitala neysluverðs Vísitala': 'cpi'})
    return data

if __name__ == '__main__':
    df = fetch_data()
    df.to_csv('cpi_data.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 31
#      28     return data
#      30 if __name__ == '__main__':
# ---> 31     df = fetch_data()
#      32     df.to_csv('cpi_data.csv', index=False)
#
# Cell In[19], line 21, in fetch_data()
#      18 response_text = response.text
#      19 data = pd.read_csv(StringIO(response_text))
# ---> 21 data = data.loc[:, ['Mánuður', 'Vísitala neysluverðs Vísitala']]
#      22 # Fix format: 1988M05
#      23 data['Mánuður'] = pd.to_datetime(data['Mánuður'], format='%YM%m')
#
# File c:\Users\sverrirhd\venvs\VNV\lib\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
# ...

# %%
import pandas as pd
import requests
from io import StringIO

# API URL and request parameters
url = "https://px.hagstofa.is:443/pxis/api/v1/is/Efnahagur/visitolur/1_vnv/1_vnv/VIS01000.px"
params = {
  "query": [],
  "response": {
    "format": "csv"
  }
}

# %%
def fetch_data():
    response = requests.post(url, json=params)
    response.raise_for_status()
    response_text = response.text
    data = pd.read_csv(StringIO(response_text))
    
    data = data.loc[:, ['Mánuður', 'Vísitala neysluverðs Vísitala']]
    # Fix format: 1988M05
    data['Mánuður'] = pd.to_datetime(data['Mánuður'], format='%YM%m')
    # rename to date
    data = data.rename(columns={'Mánuður': 'date'})
    # rename to cpi
    data = data.rename(columns={'Vísitala neysluverðs Vísitala': 'cpi'})
    return data

if __name__ == '__main__':
    df = fetch_data()
    df.to_csv('cpi_data.csv')

# %%
df
# Out:
#        Mánuður  Vísitala neysluverðs Vísitala
# 0   1988-05-01                          100.0
# 1   1988-06-01                          103.4
# 2   1988-07-01                          107.0
# 3   1988-08-01                          109.3
# 4   1988-09-01                          110.0
# ..         ...                            ...
# 414 2022-11-01                          560.9
# 415 2022-12-01                          564.6
# 416 2023-01-01                          569.4
# 417 2023-02-01                          577.3
# 418 2023-03-01                          580.7
#
# [419 rows x 2 columns]

# %%
df.to_csv('cpi_data.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.to_csv('cpi_data.csv', index=False)
#
# NameError: name 'df' is not defined

# %%
response = requests.post(url, json=params)
response.raise_for_status()

# %%
response
# Out:
# <Response [200]>

# %%
data_json = response.json()
dataset = data_json["dataset"]
cpi_data = dataset["value"]
dates = dataset["dimension"]["Mánuður"]["category"]["index"]

data = pd.DataFrame(zip(dates.keys(), cpi_data), columns=['date', 'cpi'])
data['date'] = pd.to_datetime(data['date'], format='%YM%m')

# %%
print(data_json.keys())
print(data_json['dataset'].keys())
for key in data_json['dataset'].keys():
    print(key, '\n',data_json['dataset'][key])
    print('')
# Out:
# dict_keys(['dataset'])
# dict_keys(['status', 'dimension', 'label', 'source', 'updated', 'value'])
# status
#  {'1': '.', '2': '.', '3': '.', '4': '.', '5': '.', '7': '.', '8': '.', '9': '.', '10': '.', '11': '.', '14': '.', '16': '.', '17': '.', '20': '.', '22': '.', '23': '.', '26': '.', '28': '.', '29': '.', '32': '.', '34': '.', '35': '.', '38': '.', '41': '.', '44': '.', '47': '.', '50': '.', '53': '.', '56': '.', '59': '.', '62': '.', '65': '.', '68': '.', '71': '.', '74': '.', '80': '.', '86': '.', '92': '.', '98': '.', '104': '.', '110': '.', '116': '.', '122': '.', '128': '.', '134': '.', '140': '.'}
#
# dimension
# ...

# %%
    return data

if __name__ == '__main__':
    df = fetch_data()
    df.to_csv('cpi_data.csv', index=False)

# %%
df
# Out:
#           date     cpi
# 0   1988-05-01  100.00
# 1   1988-06-01     NaN
# 2   1988-07-01     NaN
# 3   1988-08-01     NaN
# 4   1988-09-01     NaN
# ..         ...     ...
# 414 2022-11-01  152.80
# 415 2022-12-01    0.39
# 416 2023-01-01    7.00
# 417 2023-02-01    4.80
# 418 2023-03-01    5.70
#
# [419 rows x 2 columns]
